# %% [markdown]
# # Titanic Passengers
# ### Lab17: Data Visualization
# ##### Paul Leonard 12/1/2020

# %% [markdown]
# Importing data and libraries
# Data Source:  built in seaborn titanic dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

df = sns.load_dataset("titanic")
df.describe
# Out:
# <bound method NDFrame.describe of      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %% [markdown]
# ## What is the age distribution of the people who were traveling on the Titanic?

# %%
age_chart = sns.countplot(data=df[["age"]],x="age").set_title("Titantic Passenger Ages (partial data set)")
# age_chart.set_major_locator(ticker.MultipleLocator(5))
# age_chart.set_major_formatter(ticker.ScalarFormatter())
#.set(set_xticks=[0,5,80])
print()

# %% [markdown]
# ## What was the age distribution of the survivors?

# %%
df_sur = df[df["survived"]==1][["age","survived"]]
age_sur_chart = sns.countplot(data=df_sur[["age"]],x="age").set_title("Titantic Survivor Ages")
print()

# %% [markdown]
# ## How about looking at those ages again, but taking into consideration the gender of the survivors as well...

# %%
table_age_and_sex = (df
    .groupby(["sex","age"])
    .size()
    .unstack()
)

plt.figure(figsize=(16,22))
heatmap2 = sns.heatmap(
    table_age_and_sex,
    square=True,
    cbar_kws={'fraction' : 0.01},
    cmap='OrRd',
    linewidth=0,
)

heatmap2.set_title("Titantic Survivors by Age and Sex")
print()

# %% [markdown]
# ## Insights and Conclusion
# - I am surprised so many people in the late-teen to mid-thirties died during the sinking of the Titanic.
# - However... from the first histogram, it showed that a majority of passengers who boarded the ship were in that age group.
# - It does seem to make sense because they are the age group more likely to travel off to a new world.
# - From looking at the gender plot, it looks like a lot more men died than women.
# - While that is true, it does not mean that more women died in the sinking.
# - The next thing to investigate would be the last heat map, but with color hue being based on percentage of total survivors instead of individual counts.
